# %% [markdown]
# **This notebook is an exercise in the [Data Visualization](https://www.kaggle.com/learn/data-visualization) course.  You can reference the tutorial at [this link](https://www.kaggle.com/alexisbcook/final-project).**
#
# ---

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
my_filepath = '../input/electricity-production-by-source-world/Electricity_Production_By_Source.csv'
energy_data = pd.read_csv(my_filepath , index_col = 'Year')
del energy_data['Code']
energy_data = energy_data.rename(columns = {'Entity':'Country'})

energy_data
# Out:
#           Country  Electricity from coal (TWh)  Electricity from gas (TWh)  \
# Year
# 2000  Afghanistan                     0.000000                       0.155
# 2001  Afghanistan                     0.000000                       0.094
# 2002  Afghanistan                     0.000000                       0.132
# 2003  Afghanistan                     0.000000                       0.309
# 2004  Afghanistan                     0.000000                       0.329
# ...           ...                          ...                         ...
# 2015     Zimbabwe                     4.311780                       0.000
# 2016     Zimbabwe                     3.714880                       0.000
# 2017     Zimbabwe                     3.218560                       0.000
# 2018     Zimbabwe                     3.932020                       0.000
# 2019     Zimbabwe                     3.805433                       0.000
#
#       Electricity from hydro (TWh)  Electricity from other renewables (TWh)  \
# Year
# 2000                         0.312                                 0.000000
# 2001                         0.498                                 0.000000
# 2002                         0.555                                 0.000000
# 2003                         0.630                                 0.000000
# 2004                         0.565                                 0.000000
# ...                            ...                                      ...
# 2015                         4.940                                 0.128000
# 2016                         2.955                                 0.147000
# 2017                         3.929                                 0.151000
# 2018                         5.000                                 0.187000
# 2019                         5.020                                 0.206667
#
#       Electricity from solar (TWh)  Electricity from oil (TWh)  \
# Year
# 2000                         0.000                         0.0
# 2001                         0.000                         0.0
# 2002                         0.000                         0.0
# 2003                         0.000                         0.0
# 2004                         0.000                         0.0
# ...                            ...                         ...
# 2015                         0.008                         0.0
# 2016                         0.009                         0.0
# 2017                         0.011                         0.0
# 2018                         0.014                         0.0
# 2019                         0.014                         0.0
#
#       Electricity from wind (TWh)  Electricity from nuclear (TWh)
# Year
# 2000                          0.0                             0.0
# 2001                          0.0                             0.0
# 2002                          0.0                             0.0
# 2003                          0.0                             0.0
# 2004                          0.0                             0.0
# ...                           ...                             ...
# 2015                          0.0                             0.0
# 2016                          0.0                             0.0
# 2017                          0.0                             0.0
# 2018                          0.0                             0.0
# 2019                          0.0                             0.0
#
# [6241 rows x 9 columns]

# %%
country = 'Canada'
plot_data = energy_data.loc[energy_data['Country'] == country]
plt.figure(figsize=(25,8))
plt.title("Energy production " + country, size = 15)
sns.lineplot(data = plot_data)
plt.ylabel("TWh" , size = 15)
plt.xlabel("Year", size = 15)
plt.legend(fontsize = 14)

# %%
column_names = list(energy_data)
del column_names[0]

# %%
energy_data['Max energy production source'] = energy_data[column_names].idxmax(axis=1)
energy_data.head(30)
# Out:
#           Country  Electricity from coal (TWh)  Electricity from gas (TWh)  \
# Year
# 2000  Afghanistan                     0.000000                      0.1550
# 2001  Afghanistan                     0.000000                      0.0940
# 2002  Afghanistan                     0.000000                      0.1320
# 2003  Afghanistan                     0.000000                      0.3090
# 2004  Afghanistan                     0.000000                      0.3290
# 2005  Afghanistan                     0.000000                      0.3440
# 2006  Afghanistan                     0.000000                      0.2000
# 1991                        0.0000                   42.202621
# 1992                        0.0000                   42.742592
# 1993                        0.0000                   41.905016
# 1994                        0.0000                   39.929520
#
#       Electricity from wind (TWh)  Electricity from nuclear (TWh)  \
# Year
# 2000                      0.00000                           0.000
# 2001                      0.00000                           0.000
# 2002                      0.00000                           0.000
# 2003                      0.00000                           0.000
# 2004                      0.00000                           0.000
# 2005                      0.00000                           0.000
# 2006                      0.00000                           0.000
# 2007                      0.00000                           0.000
# 2008                      0.00001                           0.000
# 2009                      0.00010                           0.000
# 2010                      0.00010                           0.000
# 2011                      0.00010                           0.000
# 2012                      0.00000                           0.000
# 2013                      0.00000                           0.000
# 2014                      0.00000                           0.000
# 2015                      0.00000                           0.000
# 2016                      0.00000                           0.000
# 2017                      0.00000                           0.000
# 2018                      0.00000                           0.000
# 2019                      0.00000                           0.000
# 1985                      0.00000                           5.315
# 1986                      0.00000                           8.803
# 1987                      0.00000                           6.167
# 1988                      0.00000                          10.493
# 1989                      0.00000                          11.099
# 1990                      0.00000                           8.449
# 1991                      0.00000                           9.144
# 1992                      0.00000                           9.288
# 1993                      0.00200                           7.255
# 1994                      0.00540                           9.697
#
#       Max energy production source
# Year
# 2000  Electricity from hydro (TWh)
# 2001  Electricity from hydro (TWh)
# 2002  Electricity from hydro (TWh)
# 2003  Electricity from hydro (TWh)
# 2004  Electricity from hydro (TWh)
# 2005  Electricity from hydro (TWh)
# 2006  Electricity from hydro (TWh)
# 2007  Electricity from hydro (TWh)
# 2008  Electricity from hydro (TWh)
# 2009  Electricity from hydro (TWh)
# 2010  Electricity from hydro (TWh)
# 2011  Electricity from hydro (TWh)
# 2012  Electricity from hydro (TWh)
# 2013  Electricity from hydro (TWh)
# 2014  Electricity from hydro (TWh)
# 2015  Electricity from hydro (TWh)
# 2016  Electricity from hydro (TWh)
# 2017  Electricity from hydro (TWh)
# 2018  Electricity from hydro (TWh)
# 2019  Electricity from hydro (TWh)
# 1985   Electricity from coal (TWh)
# 1986   Electricity from coal (TWh)
# 1987   Electricity from coal (TWh)
# 1988   Electricity from coal (TWh)
# 1989   Electricity from coal (TWh)
# 1990   Electricity from coal (TWh)
# 1991   Electricity from coal (TWh)
# 1992   Electricity from coal (TWh)
# 1993   Electricity from coal (TWh)
# 1994   Electricity from coal (TWh)

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/data-visualization/discussion) to chat with other learners.*

# %%
import plotly.express as px  

fig = px.choropleth(energy_data,  # Input Pandas DataFrame
                    locations = "Country",  # DataFrame column with locations
                    color = "Max energy production source",  # DataFrame column with color values
                    hover_name = "Country", # DataFrame column hover info
                    locationmode = 'country names') # Set to plot as US States
fig.update_layout(title_text = 'Max energy production source for each country',geo_scope = 'world')  # Plot only the USA instead of globe
fig.show()  # Output the plot to the screen
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="fbbd3b8d-d6af-464b-a5fa-238b4c48df36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbbd3b8d-d6af-464b-a5fa-238b4c48df36")) {                    Plotly.newPlot(                        "fbbd3b8d-d6af-464b-a5fa-238b4c48df36",                        [{"colorscale":[[0.0,"#636efa"],[1.0,"#636efa"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Max energy production source=Electricity from hydro (TWh)<br>Country=%{location}<extra></extra>","hovertext":["Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Armenia","Armenia","Armenia","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belarus","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Belize","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bhutan","Bolivia","Bolivia","Bolivia","Bosnia and Herzegovina","Bosnia and Herzegovina","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Burundi","Cambodia","Cambodia","Cambodia","Cambodia","Cambodia","Cambodia","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Cameroon","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada ...
